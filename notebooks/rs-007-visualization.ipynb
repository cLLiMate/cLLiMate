# %%
import pandas as pd
import pyarrow
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_parquet("../data/processed/news-consolidated-v1.parquet")
data["years"] = data["date"].dt.year
nature = data[data["source"] == "nature"]
nature["years"].value_counts().sort_index().to_json("../data/vis/numNature.json")
nature["years"].value_counts().sort_index().plot(kind="bar", title="Nature")
plt.show()
print("Insight: Nature has not been publishing more articles over the years. It has remained at roughly 10.5k throughout the 2010s. Yet, the spike indicates an exponential increase in climate papers. This proves that a greater chunk of submissions are regarding climate and environmental concerns.")
climate = data[data["source"] == "climate-db"]
climate["years"].value_counts().sort_index()[9:].plot(kind="bar", title="Climate")
climate["years"].value_counts().sort_index()[9:].to_json("../data/vis/numClimate.json")
plt.show()
abc = data[data["source"] == "abc"]
abc["years"].value_counts().sort_index().plot(kind="bar", title="ABC")
abc["years"].value_counts().sort_index().to_json("../data/vis/numABC.json")
plt.show()
# Out:
# Insight: Nature has not been publishing more articles over the years. It has remained at roughly 10.5k throughout the 2010s. Yet, the spike indicates an exponential increase in climate papers. This proves that a greater chunk of submissions are regarding climate and environmental concerns.
# /var/folders/7h/8hn0w0xs40n29dcvw_5nqwch0000gn/T/ipykernel_22424/458861544.py:9: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   climate["years"].value_counts().sort_index()[9:].plot(kind="bar", title="Climate")
# /var/folders/7h/8hn0w0xs40n29dcvw_5nqwch0000gn/T/ipykernel_22424/458861544.py:10: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   climate["years"].value_counts().sort_index()[9:].to_json("../data/vis/numClimate.json")
