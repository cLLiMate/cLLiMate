# %% [markdown]
# # LDA for headlines

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import pprint

import nltk

from gensim.corpora import Dictionary
from gensim.models import LdaModel

# Download NLTK data
nltk.download("stopwords", quiet=True)
nltk.download("wordnet", quiet=True)
nltk.download("omw-1.4", quiet=True)
# Out:
# True

# %% [markdown]
# ## Load & Preprocess Data

# %%
# Load the data
path_to_data = "../data/processed/headlines.csv"
data = pd.read_csv(path_to_data, nrows=1000)

# %%
data
# Out:
#          org                                           headline
# 0    nytimes                 Obama Affirms Climate Change Goals
# 1    nytimes      How Investors Are Addressing Racial Injustice
# 2    nytimes  Two New Books Dramatically Capture the Climate...
# 3    nytimes  In the Fight Against Climate Change, Young Voi...
# 4    nytimes  Climate Change Is Making It Harder for Campers...
# ..       ...                                                ...
# 995  nytimes  Boris Johnson’s ‘Global Britain’: Inspired Vis...
# 996  nytimes  Opinion | How Can We Fix Income and Wealth Ine...
# 997  nytimes  Biden Tells Officials to Prepare for Climate C...
# 998  nytimes  Humans Are Speeding Extinction and Altering th...
# 999  nytimes   Opinion | What Biden Can Do About Climate Change
#
# [1000 rows x 2 columns]

# %%
# fetch just the headlines from the data and convert to a list
headlines = data["headline"].tolist()

# %%
# Tokenize the documents.
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer

# Split the documents into tokens.
tokenizer = RegexpTokenizer(r"\w+")
for idx in range(len(headlines)):
    # Remove punctuation and lowercase the documents.
    headlines[idx] = tokenizer.tokenize(headlines[idx])
    headlines[idx] = [w.lower() for w in headlines[idx] if len(w) > 1]

# Remove stopwords and lemmatize the documents
stop_words = stopwords.words("english")
lemmatizer = WordNetLemmatizer()

for idx in range(len(headlines)):
    headlines[idx] = [w for w in headlines[idx] if not w in stop_words]
    headlines[idx] = [lemmatizer.lemmatize(token) for token in headlines[idx]]

# %%
headlines
# Out:
# [['obama', 'affirms', 'climate', 'change', 'goal'],
#  ['investor', 'addressing', 'racial', 'injustice'],
#  ['two',
#   'new',
#   'book',
#   'dramatically',
#   'capture',
#   'climate',
#   'change',
#   'crisis'],
#  ['fight', 'climate', 'change', 'young', 'voice', 'speak'],
#  ['climate', 'change', 'making', 'harder', 'camper', 'beat', 'heat'],
#  ['inquiry',
#   'prompted',
#   'trump',
#   'hurricane',
#   'dorian',
#   'claim',
#   'blocked',
#   'investigator',
#   'say'],
#  ['california', 'tourism', 'survive', 'climate', 'change'],
#  ['opinion',
#   'make',
#   'headway',
#   'climate',
#   'change',
#   'let',
#   'change',
#   'subject'],
#  ['climate', 'change', 'enters', 'therapy', 'room'],
#  ['fighting', 'climate', 'change', 'even', 'landing', 'punch'],
#  ['response',
#   'climate',
#   'change',
#   'missing',
#   'something',
#   'big',
#   'scientist',
#   'say'],
#  ['medical',
#   'journal',
#   'call',
#   'climate',
#   'change',
#   'greatest',
#   'threat',
#   'global',
#   'public',
#   'health'],
#  ['policing', 'climate', 'change', 'sweeping', 'call', 'moral', 'revolution'],
#  ['opinion', 'climate', 'change', 'trump', 'age', 'ignorance'],
#  ['effect', 'climate', 'change'],
#  ['learn', 'online', 'privacy', 'climate', 'change'],
#  ['google', 'stop', 'serving', 'ad', 'climate', 'change', 'misinformation'],
#  ['strongest',
#   'climate',
#   'ruling',
#   'yet',
#   'dutch',
#   'court',
#   'order',
#   'leader',
#   'take',
#   'action'],
#  ['teach', 'climate', 'change', '24', 'new', 'york', 'time', 'graph'],
#  ['antarctic', 'signaling', 'big', 'climate', 'trouble'],
#  ['severe',
#   'drought',
#   'worsened',
#   'climate',
#   'change',
#   'ravage',
#   'american',
#   'west'],
#  ['iciest', 'water', 'around', 'antarctica', 'le', 'icy'],
#  ['coronavirus', 'climate', 'change'],
#  ['climate', 'changed', 'blamed', 'worsening', 'flooding', 'europe'],
#  ['yes', 'progress', 'climate', 'nearly', 'enough'],
#  ['china', 'boomed', 'take', 'climate', 'change', 'account', 'must'],
#  ['opinion', 'china', 'india', 'make', 'big', 'stride', 'climate', 'change'],
#  ['biden', 'urge', 'climate', 'action', 'much', '10', 'year'],
#  ['poll',
#   'find',
#   'global',
#   'consensus',
#   'need',
#   'tackle',
#   'climate',
#   'change'],
#  ['biden', 'host', 'meeting', 'climate', 'change', 'world', 'leader'],
#  ['opinion', 'geoegineering', 'fix', 'climate', 'change'],
#  ['opinion', 'joe', 'biden', 'best', 'running', 'mate', 'cabinet', 'pick'],
#  ['cop26',
#   'protester',
#   'back',
#   'array',
#   'cause',
#   'connected',
#   'climate',
#   'change'],
#  ['late', 'night', 'show', 'teaming', 'tackle', 'climate', 'change'],
#  ['climate', 'change', 'california', 'favorite', 'tree'],
#  ['losing', 'earth', 'decade', 'almost', 'stopped', 'climate', 'change'],
#  ['industry', 'awakens', 'threat', 'climate', 'change'],
#  ['sunday', 'read', 'fighting', 'climate', 'change', 'whatever', 'take'],
#  ['arctic',
#   'shift',
#   'warmer',
#   'climate',
#   'well',
#   'underway',
#   'scientist',
#   'warn'],
#  ['like',
#   'terror',
#   'movie',
#   'climate',
#   'change',
#   'cause',
#   'simultaneous',
#   'disaster'],
#  ['opinion', 'scene', 'world', 'fire'],
#  ['global', 'warming', 'climate', 'change', 'forecasting'],
#  ['supreme', 'court', 'hear', 'case', 'voting', 'right', 'climate', 'change'],
#  ['climate',
#   'talk',
#   'biden',
#   'try',
#   'sell',
#   'american',
#   'leadership',
#   'skeptic'],
#  ['opinion', 'climate', 'change', 'exodus', 'specie'],
#  ['global', 'climate', 'change', 'talk', 'begin', 'cancún'],
#  ['opinion', 'conservative', 'christian', 'environmentalist', 'oxymoron'],
#  ['major',
#   'climate',
#   'report',
#   'describes',
#   'strong',
#   'risk',
#   'crisis',
#   'early',
#   '2040'],
#  ['biden',
#   'world',
#   'leader',
#   'focus',
#   'innovation',
#   'clean',
#   'energy',
#   'future'],
#  ['opinion', 'playing', 'dumb', 'climate', 'change'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['interior',
#   'dept',
#   'report',
#   'drilling',
#   'mostly',
#   'silent',
#   'climate',
#   'change'],
#  ['global', 'warming', 'fueled', 'five', 'extreme', 'weather', 'event'],
#  ['japan', 'deadly', 'combination', 'climate', 'change', 'aging', 'society'],
#  ['debate',
#   'pledge',
#   'transition',
#   'oil',
#   'put',
#   'climate',
#   'center',
#   'campaign',
#   'finale'],
#  ['opinion', 'sign', 'climate', 'change'],
#  ['america',
#   'heartland',
#   'discussing',
#   'climate',
#   'change',
#   'without',
#   'saying',
#   'climate',
#   'change'],
#  ['billion',
#   'infrastructure',
#   'funding',
#   'could',
#   'worsen',
#   'global',
#   'warming'],
#  ['obama', 'speech', 'climate', 'change'],
#  ['climate', 'change', '2020', 'hurricane', 'record', 'know'],
#  ['executive',
#   'call',
#   'deep',
#   'emission',
#   'cut',
#   'combat',
#   'climate',
#   'change'],
#  ['amid',
#   'biden',
#   'climate',
#   'push',
#   'question',
#   'loom',
#   'america',
#   'word',
#   'good'],
#  ['oil', 'company', 'ponder', 'climate', 'change', 'profit', 'still', 'rule'],
#  ['john',
#   'kerry',
#   'likens',
#   'climate',
#   'inaction',
#   'global',
#   'suicide',
#   'pact'],
#  ['fresh',
#   'water',
#   'grows',
#   'scarcer',
#   'could',
#   'become',
#   'good',
#   'investment'],
#  ['green', 'new', 'deal', 'climate', 'proposal', 'explained'],
#  ['message', 'reusable', 'wine', 'bottle', 'combat', 'climate', 'change'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['researcher',
#   'link',
#   'syrian',
#   'conflict',
#   'drought',
#   'made',
#   'worse',
#   'climate',
#   'change'],
#  ['jaw', 'still', 'devouring', 'u', 'so'],
#  ['economic', 'impact', 'climate', 'change', 'europe', 'scrutinized'],
#  ['key', 'moment', 'day', 'cop26', 'climate', 'change', 'summit'],
#  ['asked', '2020', 'democrat', 'climate', 'change', 'yes', 'idea'],
#  ['tiny', 'swiss', 'company', 'think', 'help', 'stop', 'climate', 'change'],
#  ['infrastructure', 'bill', 'climate', 'change'],
#  ['climate', 'change', 'giant', 'impact', 'economy', 'key', 'issue'],
#  ['climate', 'scientist', 'fed', 'ready', 'go', 'strike'],
#  ['climate', 'change', 'effect', 'outpacing', 'ability', 'adapt', 'warns'],
#  ['opinion', 'rich', 'country', 'climate', 'change', 'responsibility'],
#  ['opinion', 'pakistan', 'terrifying', 'adversary', 'climate', 'change'],
#  ['save',
#   'climate',
#   'change',
#   'force',
#   'brutal',
#   'choice',
#   'national',
#   'park'],
#  ['opinion', 'climate', 'change', 'must', 'done'],
#  ['venice', 'tourism', 'may', 'never', 'covid', 'might', 'good', 'thing'],
#  ['opinion', 'cancer', 'climate', 'change'],
#  ['hollywood', 'scared', 'climate', 'change'],
#  ['panel', 'issue', 'bleak', 'report', 'climate', 'change'],
#  ['virus', 'climate', 'intersect'],
#  ['opinion', 'america', 'give', 'covid', '19', 'republican'],
#  ['calling',
#   'climate',
#   'change',
#   'controversial',
#   'barrett',
#   'created',
#   'controversy'],
#  ['apple',
#   'popcorn',
#   'climate',
#   'change',
#   'altering',
#   'food',
#   'america',
#   'grows'],
#  ['vatican',
#   'tenet',
#   'faith',
#   'seen',
#   'crucial',
#   'climate',
#   'change',
#   'effort'],
#  ['trump',
#   'called',
#   'climate',
#   'change',
#   'chinese',
#   'hoax',
#   'beijing',
#   'say',
#   'anything'],
#  ['trump',
#   'eliminates',
#   'major',
#   'methane',
#   'rule',
#   'even',
#   'leak',
#   'worsening'],
#  ['intense', 'arctic', 'wildfire', 'set', 'pollution', 'record'],
#  ['climate', 'change', 'making', 'winter', 'ice', 'dangerous'],
#  ['opinion', 'climate', 'change', 'anxiety', 'therapy'],
#  ['climate', 'change', 'lesson', 'fighting', 'coronavirus'],
#  ['attack', 'climate', 'change'],
#  ['stopping',
#   'climate',
#   'change',
#   'doable',
#   'time',
#   'short',
#   'panel',
#   'warns'],
#  ['michael', 'bloomberg', 'promise', '500', 'million', 'help', 'end', 'coal'],
#  ['opinion', 'apocalypse', 'becomes', 'new', 'normal'],
#  ['opinion', 'coronavirus', 'mean', 'climate', 'change'],
#  ['wildlife',
#   'collapse',
#   'climate',
#   'change',
#   'predicted',
#   'hit',
#   'suddenly',
#   'sooner'],
#  ['much', 'planet', 'warm', 'carbon', 'dioxide', 'level', 'double'],
#  ['study', 'find', 'climate', 'change', 'threat', 'specie'],
#  ['said', 'davos', 'climate', 'change'],
#  ['biden', 'promised', 'delivered', 'climate', 'trouble', 'loom', '2022'],
#  ['company',
#   'see',
#   'climate',
#   'change',
#   'hitting',
#   'bottom',
#   'line',
#   'next',
#   'year'],
#  ['considers', 'climate', 'disclosure', 'rule'],
#  ['obama', 'climate', 'change', 'trend', 'terrifying'],
#  ['australia', 'burn', 'climate', 'change', 'denier', 'rally', 'troop'],
#  ['opinion', 'big', 'business', 'undisclosed', 'climate', 'crisis', 'plan'],
#  ['blamed',
#   'climate',
#   'change',
#   'oil',
#   'company',
#   'invest',
#   'carbon',
#   'removal'],
#  ['climate', 'change', 'strike', 'heart', 'german', 'identity', 'wood'],
#  ['climate', 'change', 'inflicts', 'toll', 'mental', 'health'],
#  ['trump', 'pattern', 'denial', 'virus', 'russia', 'climate', 'change'],
#  ['plant', 'animal', 'utterly', 'confused', 'climate', 'change'],
#  ['opinion', 'climate', 'scientist', 'belief', 'god', 'hear'],
#  ['new', 'rule', 'california', 'require', 'zero', 'emission', 'truck'],
#  ['opinion', 'west', 'fire', 'past', 'time', 'act', 'climate', 'change'],
#  ['global',
#   'vaccine',
#   'crisis',
#   'sends',
#   'ominous',
#   'signal',
#   'fighting',
#   'climate',
#   'change'],
#  ['20',
#   'foot',
#   'sea',
#   'wall',
#   'miami',
#   'face',
#   'hard',
#   'choice',
#   'climate',
#   'change'],
#  ['city', 'love', 'climate', 'change', 'miami', 'story'],
#  ['chief', 'doubt', 'consensus', 'view', 'climate', 'change'],
#  ['fighting', 'climate', 'change', 'individual'],
#  ['opinion', 'climate', 'change', 'becomes', 'credit', 'problem'],
#  ['conservative',
#   'state',
#   'seek',
#   'billion',
#   'brace',
#   'disaster',
#   'call',
#   'climate',
#   'change'],
#  ['world', 'ocean', 'danger', 'major', 'climate', 'change', 'report', 'warns'],
#  ['visualizing', 'invisible', 'driver', 'climate', 'change'],
#  ['rising',
#   'sea',
#   'threaten',
#   'american',
#   'institution',
#   '30',
#   'year',
#   'mortgage'],
#  ['biden',
#   'open',
#   'new',
#   'federal',
#   'office',
#   'climate',
#   'change',
#   'health',
#   'equity'],
#  ['biden', 'launch', 'climate', 'change', 'effort'],
#  ['opinion', 'want', 'convince', 'climate', 'change', 'skeptic'],
#  ['europe',
#   'heat',
#   'wave',
#   'fueled',
#   'climate',
#   'change',
#   'move',
#   'greenland'],
#  ['climate', 'change', 'affecting', 'winter', 'storm'],
#  ['climate',
#   'change',
#   'activist',
#   'notch',
#   'victory',
#   'exxon',
#   'mobil',
#   'board',
#   'election'],
#  ['opinion', 'third', 'way', 'fight', 'climate', 'change'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['amazon', 'accelerates', 'effort', 'fight', 'climate', 'change'],
#  ['child', 'climate', 'change', 'people', 'considering'],
#  ['climate', 'change', 'longer', 'future', 'adaptation', 'speed'],
#  ['went', 'wrong', 'brazil'],
#  ['biden', 'big', 'climate', 'decision', 'embrace', 'task', 'force', 'goal'],
#  ['nerve', 'center', 'climate', 'biden', 'white', 'house'],
#  ['opinion', 'depravity', 'climate', 'change', 'denial'],
#  ['explore', 'climate', 'change', 'solution'],
#  ['winner', 'third', 'annual', 'podcast', 'contest'],
#  ['opinion', 'culture', 'survive', 'climate', 'change'],
#  ['knitter', 'chronicle', 'climate', 'change', 'one', 'stitch', 'time'],
#  ['opinion', 'lesson', 'climate', 'change', '2008', 'recession'],
#  ['happened', 'day', 'cop26', 'climate', 'change', 'summit'],
#  ['central', 'american', 'farmer', 'head', 'fleeing', 'climate', 'change'],
#  ['john', 'houghton', 'sounded', 'alarm', 'climate', 'change', 'dy', '88'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['documenting', 'climate', 'change', 'air', 'land', 'sea'],
#  ['opinion',
#   'biden',
#   'want',
#   'spend',
#   'billion',
#   'fight',
#   'climate',
#   'change',
#   'enough'],
#  ['global',
#   'wealth',
#   'gap',
#   'would',
#   'smaller',
#   'today',
#   'without',
#   'climate',
#   'change',
#   'study',
#   'find'],
#  ['two',
#   'trump',
#   'appointee',
#   'investigated',
#   'posting',
#   'report',
#   'denying',
#   'climate',
#   'change'],
#  ['soccer', 'avoid', 'climate', 'change', 'forever'],
#  ['federal', 'report', 'warns', 'financial', 'havoc', 'climate', 'change'],
#  ['coronavirus', 'done', 'new', 'development'],
#  ['summer', 'disaster', 'lawmaker', 'see', 'chance', 'climate', 'action'],
#  ['scientist', 'study', 'link', 'climate', 'change', 'extreme', 'weather'],
#  ['opinion', 'climate', 'change', 'cause', 'deadly', 'tornado'],
#  ['fedex', 'join', 'push', 'washington', 'redskin', 'renamed'],
#  ['looking', 'quickly', 'fingerprint', 'climate', 'change'],
#  ['year', 'climate', 'change'],
#  ['opinion',
#   'climate',
#   'change',
#   'inconvenient',
#   'existential',
#   'supercomputer',
#   'math'],
#  ['biggest', 'threat', 'humanity', 'climate', 'change', 'chief', 'say'],
#  ['latino', 'back', 'black', 'life', 'matter', 'protest', 'want', 'change'],
#  ['opinion', 'climate', 'change', 'expensive', 'resist', 'city', 'adapt'],
#  ['new', 'york', 'clock', 'told', 'time', 'tell', 'time', 'remaining'],
#  ['warns', 'climate', 'pose', 'emerging', 'threat', 'financial', 'system'],
#  ['climate', 'crisis', 'catch', 'power', 'company', 'unprepared'],
#  ['climate', 'disruption', 'locked', 'next', 'move', 'crucial'],
#  ['trump', 'climate', 'policy', 'accelerated', 'global', 'warming'],
#  ['climate',
#   'change',
#   'contributed',
#   'europe',
#   'deadly',
#   'flood',
#   'study',
#   'find'],
#  ['trump', 'insider', 'embeds', 'climate', 'denial', 'scientific', 'research'],
#  ['thing', 'biden', 'administration', 'could', 'quickly', 'environment'],
#  ['bad', 'climate', 'change'],
#  ['trump', 'administration', 'hardens', 'attack', 'climate', 'science'],
#  ['opinion',
#   'climate',
#   'change',
#   'climate',
#   'disaster',
#   'must',
#   'take',
#   'center',
#   'stage'],
#  ['chief', 'warns', 'dangerous', 'tipping', 'point', 'climate', 'change'],
#  ['hotter', 'future', 'certain', 'according', 'climate', 'report'],
#  ['pressure', 'block', 'declaration', 'climate', 'change', 'arctic', 'talk'],
#  ['covid', '19', 'made', 'easier', 'talk', 'climate', 'change'],
#  ['democrat',
#   'detail',
#   'climate',
#   'agenda',
#   'tying',
#   'environment',
#   'racial',
#   'justice'],
#  ['expect', 'climate', 'change', 'raise', 'risk', 'dam', 'failure'],
#  ['takeaway', 'climate', 'report'],
#  ['warns', 'high', 'cost', 'climate', 'change'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['biden', 'pledge', 'ambitious', 'climate', 'action', 'could', 'actually'],
#  ['china', 'pointed', 'message', 'tightens', 'climate', 'target'],
#  ['opinion', 'finding', 'stave', 'darker', 'future'],
#  ['climate', 'change', 'take', 'center', 'stage', 'davos'],
#  ['opinion', 'wobbling', 'climate', 'change'],
#  ['social', 'distancing', 'might', 'fighting', 'climate', 'change'],
#  ['europe',
#   'roll',
#   'ambitious',
#   'climate',
#   'change',
#   'plan',
#   'obstacle',
#   'loom'],
#  ['third', 'heat', 'death', 'tied', 'climate', 'change', 'study', 'say'],
#  ['seeing', 'world', 'help', 'ruin', 'stay', 'home'],
#  ['escape', 'harshest', 'effect', 'climate', 'change'],
#  ['secret',
#   'recording',
#   'reveals',
#   'oil',
#   'executive',
#   'private',
#   'view',
#   'climate',
#   'change'],
#  ['build',
#   'back',
#   'better',
#   'hit',
#   'wall',
#   'climate',
#   'action',
#   'could',
#   'move',
#   'forward'],
#  ['texas',
#   'blackout',
#   'point',
#   'coast',
#   'coast',
#   'crisis',
#   'waiting',
#   'happen'],
#  ['expert', 'climate', 'change', 'pondering', 'urgent'],
#  ['big', 'tech', 'versus', 'climate', 'change'],
#  ['climate',
#   'change',
#   'threatens',
#   'world',
#   'food',
#   'supply',
#   'united',
#   'nation',
#   'warns'],
#  ['european', 'oil', 'giant', 'go', 'different', 'way', 'climate', 'change'],
#  ['cloud', 'effect', 'climate', 'change', 'last', 'bastion', 'dissenter'],
#  ['black', 'environmentalist', 'talk', 'climate', 'anti', 'racism'],
#  ['government', 'study', 'warns', 'climate', 'change', 'effect'],
#  ['climate',
#   'change',
#   'destroying',
#   'country',
#   'nation',
#   'causing',
#   'must',
#   'help'],
#  ['historical', 'responsibility', 'climate', 'change'],
#  ['happened', 'friday', 'cop26', 'negotiation', 'stretch', 'night'],
#  ['game', 'made', 'beating', 'pandemic', 'fun', 'climate', 'change'],
#  ['battle', 'line', 'forming', 'biden', 'climate', 'push'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['copenhagen', 'want', 'show', 'city', 'fight', 'climate', 'change'],
#  ['australian',
#   'student',
#   'file',
#   'climate',
#   'change',
#   'lawsuit',
#   'government'],
#  ['japan', 'obsessed', 'climate', 'change', 'young', 'people', 'get'],
#  ['opinion', 'conversion', 'climate', 'change', 'skeptic'],
#  ['debt', 'climate', 'change', 'pose', 'systemic', 'risk', 'world', 'economy'],
#  ['stable', 'global', 'temperature', 'could', 'stifle', 'action', 'climate'],
#  ['travel',
#   'industry',
#   'take',
#   'crucial',
#   'first',
#   'step',
#   'toward',
#   'combating',
#   'climate',
#   'change'],
#  ['opinion', 'climate', 'change', 'corrective'],
#  ['frigid', 'weather', 'global', 'warming'],
#  ['fight', 'climate', 'change', 'forest', 'equal'],
#  ['pandemic', 'making', 'tougher', 'study', 'whale'],
#  ['climate', 'outlook', 'dire', 'next'],
#  ['climate', 'change', 'denier', 'rise', 'top', 'google', 'search'],
#  ['opinion', 'story', '2018', 'climate', 'change'],
#  ['finance', 'minister', 'grapple', 'economic', 'threat', 'climate', 'change'],
#  ['wrote', 'gardening', 'column', 'ended', 'documenting', 'climate', 'change'],
#  ['house',
#   'pass',
#   'trillion',
#   'infrastructure',
#   'package',
#   'amid',
#   'coronavirus',
#   'pandemic'],
#  ['winter', 'sweep', 'south', 'fed', 'official', 'focus', 'climate', 'change'],
#  ['deep', 'adaptation', 'science', 'climate', 'change'],
#  ['ukraine', 'war', 'politics', 'complicate', 'climate', 'change', 'fight'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['listen', 'climate', 'change', 'podcasts'],
#  ['hydrogen', 'one', 'answer', 'climate', 'change', 'getting', 'hard', 'part'],
#  ['biden',
#   'big',
#   'bet',
#   'tackling',
#   'climate',
#   'change',
#   'create',
#   'job',
#   'kill'],
#  ['earth', 'getting', 'black', 'box', 'climate', 'change'],
#  ['britain', 'enlists', 'bank', 'fight', 'climate', 'change'],
#  ['project', 'stash', 'carbon', 'dioxide', 'underground', 'get', 'boost'],
#  ['year', 'climate', 'news'],
#  ['message', 'climate', 'change', 'late'],
#  ['climate', 'change', 'survey', 'majority', 'voter', 'support', 'initiative'],
#  ['duterte',
#   'sign',
#   'antiterrorism',
#   'bill',
#   'philippine',
#   'despite',
#   'widespread',
#   'criticism'],
#  ['rupert',
#   'murdoch',
#   'news',
#   'corp',
#   'australia',
#   'ease',
#   'climate',
#   'change',
#   'denial'],
#  ['opinion', 'pope', 'climate', 'change'],
#  ['nobel', 'prize', 'physic', 'honor', 'work', 'climate', 'change'],
#  ['global', 'warming', 'could', 'unlock', 'carbon', 'tropical', 'soil'],
#  ['older', 'people', 'contributing', 'climate', 'change', 'suffering'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['opinion',
#   'climate',
#   'kid',
#   'short',
#   'circuiting',
#   'right',
#   'wing',
#   'medium'],
#  ['climate',
#   'change',
#   'california',
#   'san',
#   'francisco',
#   'face',
#   'rising',
#   'sea'],
#  ['opinion', 'major', 'breakthrough', 'climate', 'change'],
#  ['climate', 'change', 'making', 'armed', 'conflict', 'worse'],
#  ['opinion', 'climate', 'change', 'thawing', 'arctic', 'alaska'],
#  ['hurricane',
#   'fire',
#   'covid',
#   '19',
#   'disaster',
#   'expose',
#   'hard',
#   'reality',
#   'climate',
#   'change'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['trump',
#   'boost',
#   'deregulation',
#   'undervaluing',
#   'cost',
#   'climate',
#   'change'],
#  ['climate',
#   'change',
#   'deemed',
#   'growing',
#   'security',
#   'threat',
#   'military',
#   'researcher'],
#  ['hotter',
#   'planet',
#   'already',
#   'pose',
#   'fatal',
#   'risk',
#   'health',
#   'expert',
#   'warn'],
#  ['opinion',
#   'climate',
#   'change',
#   'subjective',
#   'thing',
#   'approach',
#   'environment',
#   'look',
#   'abroad'],
#  ['cop26'],
#  ['opinion', 'company', 'finally', 'step', 'fight', 'climate', 'change'],
#  ['opinion', 'credit', 'climate', 'change', 'yet'],
#  ['climate',
#   'change',
#   'influenced',
#   'western',
#   'heat',
#   'wave',
#   'analysis',
#   'find'],
#  ['climate',
#   'change',
#   'could',
#   'cut',
#   'world',
#   'economy',
#   '23',
#   'trillion',
#   '2050'],
#  ['kid', 'alright', 'era', 'climate', 'change'],
#  ['climate', 'change', 'could', 'blow', 'economy', 'bank', 'ready'],
#  ['trump', 'serf', 'notice', 'quit', 'paris', 'climate', 'agreement'],
#  ['following', 'money', 'undermines', 'climate', 'science'],
#  ['opinion', 'really', '12', 'year', 'avoid', 'climate', 'disaster'],
#  ['republican', 'try', 'new', 'tack', 'climate', 'change'],
#  ['climate', 'energy', 'expert', 'debate', 'respond', 'warming', 'world'],
#  ['climate', 'voter', 'still', 'want', 'biden'],
#  ['warming',
#   'water',
#   'moving',
#   'fish',
#   'climate',
#   'change',
#   'reshaping',
#   'iceland'],
#  ['mountain', 'ice', 'climate', 'change', 'recipe', 'disaster'],
#  ['12',
#   '000',
#   'year',
#   'ago',
#   'human',
#   'climate',
#   'change',
#   'made',
#   'deadly',
#   'team'],
#  ['climate',
#   'change',
#   'affected',
#   'australia',
#   'wildfire',
#   'scientist',
#   'confirm'],
#  ['opinion', 'climate', 'leader', 'need', 'follower'],
#  ['climate', 'change', 'altering', 'lake', 'stream', 'study', 'suggests'],
#  ['opinion', 'travel', 'ethical', 'time', 'climate', 'change'],
#  ['water', 'climate', 'change', 'drying', 'island'],
#  ['lab', 'discovered', 'global', 'warming', 'good', 'news', 'bad', 'news'],
#  ['earth',
#   'still',
#   'sailing',
#   'climate',
#   'chaos',
#   'report',
#   'say',
#   'course',
#   'could',
#   'shift'],
#  ['travel', 'tackle', 'climate', 'change'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['climate', 'change', 'effect', 'outpacing', 'ability', 'adapt', 'warns'],
#  ['ok', 'doomer', 'climate', 'advocate', 'say', 'late'],
#  ['unraveling', 'relationship', 'climate', 'change', 'health'],
#  ['art', 'reckon', 'climate', 'change'],
#  ['biden', 'speech', 'climate', 'change', 'ida', 'full', 'transcript'],
#  ['climate', 'change', 'pose', 'threat', 'child', 'health', 'worldwide'],
#  ['climate', 'change', 'ravaging', 'arctic', 'report', 'find'],
#  ['trump', 'lay', 'plan', 'reverse', 'obama', 'climate', 'change', 'legacy'],
#  ['ocean', 'heat', 'wave', 'directly', 'linked', 'climate', 'change'],
#  ['opinion', 'biden', 'climate', 'change', 'revolution'],
#  ['china', 'role', 'climate', 'change', 'possibly', 'fighting'],
#  ['majestic', 'icon', 'invasive', 'pest', 'war', 'australia', 'wild', 'horse'],
#  ['going', 'wrong', 'direction', 'tropical', 'forest', 'loss', '2019'],
#  ['opinion', 'time', 'opinion', 'sounding', 'climate', 'change', 'alarm'],
#  ['supreme',
#   'court',
#   'hear',
#   'biggest',
#   'climate',
#   'change',
#   'case',
#   'decade'],
#  ['june',
#   'hottest',
#   'record',
#   'north',
#   'america',
#   'fourth',
#   'hottest',
#   'globally'],
#  ['opinion', 'climate', 'change', 'behind', 'heat', 'dome'],
#  ['trying', 'reclaim', 'leadership', 'climate', 'change'],
#  ['opinion', 'climate', 'change', 'altering', 'favorite', 'place'],
#  ['environmental', 'justice', 'wake', 'call'],
#  ['climate',
#   'change',
#   'capitol',
#   'hill',
#   'cloris',
#   'leachman',
#   'wednesday',
#   'evening',
#   'briefing'],
#  ['opinion', 'climate', 'change', 'effect', '193', 'country'],
#  ['love', 'wine', 'contribute', 'climate', 'change'],
#  ['maine', 'lobsterman', 'perfect', 'storm', 'threatens', 'summer', 'season'],
#  ['booster', 'shot', 'climate', 'change', 'nasa', 'weekend', 'briefing'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['skateboard',
#   'climate',
#   'change',
#   'freedom',
#   'germany',
#   'next',
#   'generation',
#   'parliament'],
#  ['biden',
#   'climate',
#   'task',
#   'force',
#   'open',
#   'business',
#   'aiming',
#   'restore',
#   'credibility'],
#  ['pilate', 'business', 'love', 'hate', 'tech'],
#  ['130',
#   'mile',
#   'coast',
#   'new',
#   'jersey',
#   'mark',
#   'first',
#   'climate',
#   'change',
#   'fight'],
#  ['like',
#   'trash',
#   'landfill',
#   'carbon',
#   'dioxide',
#   'keep',
#   'piling',
#   'atmosphere'],
#  ['bleak', 'report', 'planet', 'peril', 'loom', 'new', 'climate', 'talk'],
#  ['leading', 'polluter', 'trying', 'lead', 'climate', 'change'],
#  ['climate',
#   'change',
#   'pose',
#   'systemic',
#   'threat',
#   'economy',
#   'big',
#   'investor',
#   'warn'],
#  ['saroj',
#   'khan',
#   'choreographer',
#   'made',
#   'bollywood',
#   'sparkle',
#   'dy',
#   '71'],
#  ['opinion', 'time', 'confront', 'climate', 'change'],
#  ['green', 'soggy', 'fight', 'climate', 'change'],
#  ['opinion', 'scientist', 'cracked', 'climate', 'change', 'case'],
#  ['italy',
#   'student',
#   'get',
#   'lesson',
#   'climate',
#   'change',
#   'many',
#   'lesson',
#   'fact'],
#  ['opinion', 'weather', 'fault', 'climate', 'change'],
#  ['trump',
#   'rule',
#   'would',
#   'exclude',
#   'climate',
#   'change',
#   'infrastructure',
#   'planning'],
#  ['climate', 'change', 'fund', 'try', 'profit', 'warming', 'world'],
#  ['climate', 'change', 'reporter', 'cover', 'mix', 'angst', 'ambition'],
#  ['new', 'weapon', 'climate', 'change', 'may', 'float'],
#  ['illegal', 'logging', 'blamed', 'worsening', 'flood', 'ukraine'],
#  ['siberian', 'heat', 'wave', 'yes', 'climate', 'change', 'big', 'factor'],
#  ['climate', 'change', 'hit', 'wine', 'country'],
#  ['overreacting', 'climate', 'change'],
#  ['opinion', 'group', 'shout', 'climate', 'change'],
#  ['climate',
#   'change',
#   'tied',
#   'pregnancy',
#   'risk',
#   'affecting',
#   'black',
#   'mother'],
#  ['america', 'back', 'pelosi', 'say', 'glasgow', 'climate', 'talk'],
#  ['global',
#   'warming',
#   'shift',
#   'arctic',
#   'climate',
#   'ice',
#   'snow',
#   'water',
#   'rain'],
#  ['climate',
#   'change',
#   'policy',
#   'toppled',
#   'australia',
#   'leader',
#   'mean',
#   'others'],
#  ['opinion', 'knowledge', 'ignorance', 'climate', 'change'],
#  ['climate', 'already', 'changed', 'study', 'find', 'citing', 'heat', 'flood'],
#  ['opinion', 'climate', 'change', 'action'],
#  ['kathryn',
#   'murdoch',
#   'step',
#   'family',
#   'shadow',
#   'fight',
#   'climate',
#   'change'],
#  ['china', 'friction', 'threatens', 'undercut', 'fight', 'climate', 'change'],
#  ['nfts', 'shaking', 'art', 'world', 'also', 'fueling', 'climate', 'change'],
#  ['german',
#   'high',
#   'court',
#   'hand',
#   'youth',
#   'victory',
#   'climate',
#   'change',
#   'fight'],
#  ['biden',
#   'cancel',
#   'keystone',
#   'xl',
#   'pipeline',
#   'rejoins',
#   'paris',
#   'climate',
#   'agreement'],
#  ['climate', 'reckoning', 'wildfire', 'stricken', 'california'],
#  ['rising',
#   'sea',
#   'could',
#   'menace',
#   'million',
#   'beyond',
#   'shoreline',
#   'study',
#   'find'],
#  ['election', 'nears', 'trump', 'make', 'final', 'push', 'climate', 'science'],
#  ['climate', 'week', 'america', 'cascading', 'disaster', 'dominate'],
#  ['donald',
#   'trump',
#   'could',
#   'put',
#   'climate',
#   'change',
#   'course',
#   'danger',
#   'zone'],
#  ['paris', 'agreement', 'climate', 'change', 'official'],
#  ['global', 'warming', 'deadly', 'combination', 'heat', 'humidity'],
#  ['late', 'night', 'share', 'stage', 'climate', 'change'],
#  ['australia',
#   'worst',
#   'flood',
#   'decade',
#   'quicken',
#   'concern',
#   'climate',
#   'change'],
#  ['animal', 'world', 'adapting', 'climate', 'change'],
#  ['biden', 'plan', 'move', 'fast', 'climate', 'administration'],
#  ['key', 'biden', 'climate', 'agenda', 'like', 'cut', 'manchin'],
#  ['tree', 'deal', 'climate', 'change', 'better', 'expected'],
#  ['much', 'world', 'economy', 'slowed', 'green', 'energy', 'power'],
#  ['ocean',
#   'warming',
#   'accelerating',
#   'faster',
#   'thought',
#   'new',
#   'research',
#   'find'],
#  ['one', 'safe', 'heat', 'wave', 'battered', 'wealthy', 'world'],
#  ['despite',
#   'tension',
#   'china',
#   'agree',
#   'work',
#   'together',
#   'climate',
#   'change'],
#  ['space', 'junk', 'climate', 'change', 'become', 'problem'],
#  ['opinion', 'republican', 'think', 'support', 'action', 'climate', 'change'],
#  ['opinion', 'climate', 'change', 'idiot'],
#  ['opinion', 'kind', 'problem', 'climate', 'change'],
#  ['even', 'south', 'pole', 'warming', 'quickly', 'scientist', 'say'],
#  ['opinion', 'exxon', 'deceive', 'investor', 'climate', 'change'],
#  ['finding', 'china', 'climate', 'change', 'report'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['global', 'company', 'joining', 'climate', 'change', 'effort'],
#  ['pope',
#   'francis',
#   'sweeping',
#   'encyclical',
#   'call',
#   'swift',
#   'action',
#   'climate',
#   'change'],
#  ['court',
#   'revoke',
#   'gulf',
#   'mexico',
#   'oil',
#   'gas',
#   'lease',
#   'citing',
#   'climate',
#   'change'],
#  ['make', 'climate', 'change', 'plateau'],
#  ['west',
#   'punishing',
#   'summer',
#   'heat',
#   'dry',
#   'thunderstorm',
#   'fuel',
#   'raging',
#   'wildfire'],
#  ['opinion', 'want', 'something', 'climate', 'change', 'follow', 'money'],
#  ['climate', 'change', 'lengthening', 'pollen', 'season', 'study', 'show'],
#  ['global', 'trend', 'shaping', 'climate', 'future'],
#  ['china',
#   'tell',
#   'kerry',
#   'strained',
#   'tie',
#   'could',
#   'sink',
#   'climate',
#   'cooperation'],
#  ['report',
#   'say',
#   'human',
#   'cause',
#   'climate',
#   'change',
#   'contradicting',
#   'top',
#   'trump',
#   'official'],
#  ['donald', 'trump', 'view', 'climate', 'change', 'clue', 'emerge'],
#  ['data', 'show', 'climate', 'change', 'impact', 'american'],
#  ['pentagon', 'signal', 'security', 'risk', 'climate', 'change'],
#  ['opinion', 'climate', 'change', 'doomed', 'ancient'],
#  ['climate', 'report', 'say', 'impact', 'global', 'warming'],
#  ['science', 'climate', 'change', 'explained', 'fact', 'evidence', 'proof'],
#  ['real', 'unknown', 'climate', 'change', 'behavior'],
#  ['climate', 'change', 'threatens', 'smithsonian', 'museum'],
#  ['climate',
#   'change',
#   'hammer',
#   'hitting',
#   'u',
#   'head',
#   'developing',
#   'nation',
#   'say'],
#  ['define', 'rosé'],
#  ['climate', 'change', 'bankrupting', 'america', 'small', 'town'],
#  ['pandemic', 'cleaner', 'air', 'could', 'reshape', 'know', 'atmosphere'],
#  ['disaster',
#   'cost',
#   'doubled',
#   '2020',
#   'reflecting',
#   'cost',
#   'climate',
#   'change'],
#  ['opinion', 'nuclear', 'option', 'stopping', 'climate', 'change'],
#  ['climate',
#   'change',
#   'became',
#   'largest',
#   'part',
#   'biden',
#   'spending',
#   'bill'],
#  ['senate', 'reinstates', 'obama', 'era', 'regulation', 'methane'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['compromise', 'global', 'accord', 'fight', 'climate', 'change', 'sight'],
#  ['behind', 'virus', 'report', 'jarred', 'action'],
#  ['g7',
#   'leader',
#   'get',
#   'business',
#   'taking',
#   'climate',
#   'change',
#   'pandemic'],
#  ['reversing',
#   'trump',
#   'interior',
#   'department',
#   'move',
#   'swiftly',
#   'climate',
#   'change'],
#  ['arctic',
#   'last',
#   'ice',
#   'area',
#   'may',
#   'le',
#   'resistant',
#   'global',
#   'warming'],
#  ['hurricane',
#   'climate',
#   'change',
#   'question',
#   'keep',
#   'coming',
#   'yes',
#   'linked'],
#  ['big', 'business', 'say', 'tackle', 'climate', 'change'],
#  ['know', 'climate', 'change', 'hurricane'],
#  ['climate', 'change', 'insurance', 'buy', 'land', 'somewhere', 'else'],
#  ['inured', 'climate', 'change', 'north', 'queensland'],
#  ['blackrock', 'put', 'climate', 'change', 'center', 'stage'],
#  ['climate', 'change', 'come', 'rich', 'country'],
#  ['opinion', 'climate', 'change', 'world', 'war'],
#  ['china', 'united', 'state', 'join', 'seeking', 'emission', 'cut'],
#  ['climate', 'change', 'driving', 'albatross', 'divorce', 'study', 'find'],
#  ['opinion', 'six', 'way', 'adapt', 'climate', 'change'],
#  ['opinion', 'glasgow', 'climate', 'change', 'summit', 'global', 'stake'],
#  ['fighting',
#   'plastic',
#   'paradise',
#   'lost',
#   'sister',
#   'take',
#   'climate',
#   'change'],
#  ['jeff', 'bezos', 'commits', '10', 'billion', 'address', 'climate', 'change'],
#  ['weather', 'get', 'weaponized', 'climate', 'change', 'messaging'],
#  ['climate', 'change', 'increase', 'chance', 'wildfire', 'california'],
#  ['climate',
#   'change',
#   'accelerating',
#   'bringing',
#   'world',
#   'dangerously',
#   'close',
#   'irreversible',
#   'change'],
#  ['climate',
#   'change',
#   'making',
#   'hurricane',
#   'stronger',
#   'researcher',
#   'find'],
#  ['infrastructure',
#   'bill',
#   'make',
#   'first',
#   'major',
#   'investment',
#   'climate',
#   'resilience'],
#  ['opinion', 'supreme', 'court', 'confronts', 'climate', 'change'],
#  ['opinion', 'al', 'gore', 'climate', 'crisis', 'battle', 'time', 'win'],
#  ['corporation', 'stop', 'climate', 'change'],
#  ['tasked', 'fight', 'climate', 'change', 'secretive', 'agency', 'opposite'],
#  ['trump',
#   'citing',
#   'pandemic',
#   'move',
#   'weaken',
#   'two',
#   'key',
#   'environmental',
#   'protection'],
#  ['opinion', 'let', 'work', 'latin', 'america', 'fight', 'climate', 'change'],
#  ['opinion', 'dire', 'prediction', 'climate', 'change'],
#  ['taking', 'different', 'approach', 'fighting', 'climate', 'change'],
#  ['cutting',
#   'greenhouse',
#   'gas',
#   'food',
#   'production',
#   'urgent',
#   'scientist',
#   'say'],
#  ['know', 'climate', 'connection', 'european', 'flood'],
#  ['new', 'debate', 'pricing', 'risk', 'climate', 'change'],
#  ['know', 'man', 'made', 'trump', 'say', 'climate', 'change'],
#  ['meet', 'biden', 'energy', 'climate', 'cabinet', 'contender'],
#  ['turmoil',
#   'funeral',
#   'hachalu',
#   'hundessa',
#   'show',
#   'ethiopia',
#   'combustible',
#   'politics'],
#  ['opinion', 'david', 'koch', 'ultimate', 'climate', 'change', 'denier'],
#  ['chile',
#   'writes',
#   'new',
#   'constitution',
#   'confronting',
#   'climate',
#   'change',
#   'head'],
#  ['opinion', 'price', 'ignoring', 'climate', 'change'],
#  ['child', 'teen', 'climate', 'change', 'lawsuit', 'dismissed', 'court'],
#  ['climate', 'change', 'may', 'affect', 'health'],
#  ['climate', 'change', 'debate', 'heating', 'deep', 'freeze'],
#  ['12', 'artist', 'climate', 'change'],
#  ['opinion', 'climate', 'change'],
#  ['bill', 'nye', 'say', 'way', 'talk', 'climate', 'change', 'matter'],
#  ['opinion', 'need', 'shrink', 'economy', 'stop', 'climate', 'change'],
#  ['global', 'warming', 'concern', 'rise', 'among', 'american', 'new', 'poll'],
#  ['opinion',
#   'coronavirus',
#   'bring',
#   'new',
#   'perspective',
#   'climate',
#   'change'],
#  ['opinion',
#   'greta',
#   'thunberg',
#   'strike',
#   'adult',
#   'still',
#   'failing',
#   'child',
#   'climate',
#   'change'],
#  ['climate', 'change', 'change', 'thinking'],
#  ['overlapping', 'disaster', 'expose', 'harsh', 'climate', 'reality', 'ready'],
#  ['opinion', 'stopping', 'climate', 'change', 'hopeless', 'let'],
#  ['china', 'pledge', 'carbon', 'neutral', '2060', 'mean'],
#  ['climate', 'change', 'sound', 'like'],
#  ['climate', 'change', 'biden', 'record', 'plan', 'young', 'activist', 'want'],
#  ['climate', 'change', 'news', 'stuck', 'u', '2016'],
#  ['opinion', 'wish', 'away', 'climate', 'change'],
#  ['american',
#   'link',
#   'global',
#   'warming',
#   'extreme',
#   'weather',
#   'poll',
#   'say'],
#  ['climate', 'change', 'pose', 'widening', 'threat', 'national', 'security'],
#  ['war', 'climate', 'science', 'waged', 'washington', 'rank', 'file'],
#  ['setback',
#   'aside',
#   'climate',
#   'change',
#   'finding',
#   'way',
#   'world',
#   'classroom'],
#  ['agency', 'worry', 'climate', 'threat'],
#  ['opinion', 'said', 'goodbye', 'normal'],
#  ['house', 'pass', 'largest', 'expenditure', 'climate', 'history'],
#  ['shed', 'role', 'climate', 'change', 'leader', 'fill', 'void'],
#  ['fred', 'singer', 'leading', 'climate', 'change', 'contrarian', 'dy', '95'],
#  ['responsible', 'global', 'warming'],
#  ['opinion', 'planting', 'tree', 'save', 'world'],
#  ['biden',
#   'want',
#   'world',
#   'leader',
#   'make',
#   'climate',
#   'change',
#   'commitment'],
#  ['role', 'climate', 'change', 'play', 'wind', 'storm', 'tornado'],
#  ['konrad', 'steffen', 'sounded', 'alarm', 'greenland', 'ice', 'dy', '68'],
#  ['concerned', 'climate', 'change'],
#  ['climate', 'change', 'take', 'center', 'stage', 'week', '2020', 'race'],
#  ['mayor', 'save', 'world', 'climate', 'change'],
#  ['senate',
#   'democrat',
#   'plan',
#   'revive',
#   'obama',
#   'era',
#   'climate',
#   'change',
#   'rule'],
#  ['concern', 'climate', 'change', 'rise', 'developer', 'turn', 'wood'],
#  ['russia', 'cashing', 'climate', 'change'],
#  ['five',
#   'big',
#   'way',
#   'united',
#   'state',
#   'need',
#   'adapt',
#   'climate',
#   'change'],
#  ['paul',
#   'crutzen',
#   'nobel',
#   'laureate',
#   'fought',
#   'climate',
#   'change',
#   'dy',
#   '87'],
#  ['apocalypse', 'global', 'warming', 'endless', 'scroll'],
#  ['republican',
#   'find',
#   'failure',
#   'grapple',
#   'climate',
#   'change',
#   'political',
#   'liability'],
#  ['opinion', 'joe', 'biden', 'monumental', 'environmental', 'gambit'],
#  ['biden', 'fossil', 'fuel', 'move', 'clash', 'pledge', 'climate', 'change'],
#  ['announce',
#   'rollback',
#   'auto',
#   'pollution',
#   'rule',
#   'key',
#   'effort',
#   'fight',
#   'climate',
#   'change'],
#  ['opinion', 'china', 'america', 'heading', 'toward', 'divorce'],
#  ['effort',
#   'reframe',
#   'climate',
#   'change',
#   'health',
#   'crisis',
#   'gain',
#   'steam'],
#  ['climate',
#   'donor',
#   'flock',
#   'biden',
#   'counter',
#   'trump',
#   'fossil',
#   'fuel',
#   'money'],
#  ['opinion',
#   'white',
#   'house',
#   'blocked',
#   'report',
#   'climate',
#   'change',
#   'national',
#   'security'],
#  ['risk',
#   'extreme',
#   'weather',
#   'climate',
#   'change',
#   'rise',
#   'next',
#   'century',
#   'report',
#   'say'],
#  ['opinion', 'enough', 'climate', 'change'],
#  ['opinion', 'acting', 'alone', 'climate', 'change'],
#  ['scientist', 'yet', 'close', 'racial', 'disparity'],
#  ['happened', 'final', 'day', 'cop26', 'climate', 'talk'],
#  ['teaching', 'resilience', 'face', 'climate', 'change'],
#  ['opinion', 'scientist', 'got', 'climate', 'change', 'wrong'],
#  ['opinion', 'climate', 'change', 'endgame'],
#  ['southwest',
#   'drought',
#   'rival',
#   'century',
#   'ago',
#   'thanks',
#   'climate',
#   'change'],
#  ['simulate', 'climate', 'change', 'scientist', 'build', 'miniature', 'world'],
#  ['beirut', 'hong', 'kong', 'climate', 'change', 'friday', 'briefing'],
#  ['climate', 'science', 'report', 'change', 'mind', 'bet'],
#  ['opinion', 'fighting', 'back', 'climate', 'change'],
#  ['climate', 'warms', 'plant', 'absorb', 'le', 'co₂', 'study', 'find'],
#  ['dispossessed',
#   'climate',
#   'change',
#   'hit',
#   'native',
#   'american',
#   'especially',
#   'hard'],
#  ['major',
#   'climate',
#   'change',
#   'rule',
#   'trump',
#   'administration',
#   'reversing'],
#  ['paris',
#   'accord',
#   'considers',
#   'climate',
#   'change',
#   'factor',
#   'mass',
#   'migration'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['climate', 'change', 'barely', 'registered', 'canadian', 'election'],
#  ['economic', 'giant', 'restarting', 'mean', 'climate', 'change'],
#  ['opinion', 'cashing', 'climate', 'change'],
#  ['opinion', 'let', 'climate', 'change', 'stop', 'becoming', 'parent'],
#  ['book', 'review', 'avoid', 'climate', 'disaster', 'bill', 'gate'],
#  ['coronavirus',
#   'could',
#   'slow',
#   'effort',
#   'cut',
#   'airline',
#   'greenhouse',
#   'gas',
#   'emission'],
#  ['opinion', 'america', '2090', 'impact', 'extreme', 'heat', 'map'],
#  ['john', 'kerry', 'launch', 'star', 'studded', 'climate', 'coalition'],
#  ['extremist',
#   'emboldened',
#   'capitol',
#   'attack',
#   'pose',
#   'growing',
#   'threat',
#   'homeland',
#   'security',
#   'say'],
#  ['panel', 'warning', 'climate', 'risk', 'worst', 'yet', 'come'],
#  ['opinion', 'climate', 'change'],
#  ['late',
#   'burst',
#   'climate',
#   'denial',
#   'extends',
#   'era',
#   'trump',
#   'disinformation'],
#  ['top',
#   'trump',
#   'adviser',
#   'split',
#   'paris',
#   'agreement',
#   'climate',
#   'change'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['opinion', 'climate', 'change', 'come', 'doorstep'],
#  ['alaska', 'salmon', 'catch', 'hint', 'chaos', 'climate', 'change'],
#  ['opinion', 'high', 'tech', 'capitalism', 'address', 'climate', 'change'],
#  ['panelist', 'dissent', 'climate', 'change', 'quits'],
#  ['california', 'wildfire', 'explained', 'state', 'many'],
#  ['climate', 'change', 'covid', 'transforming', 'skiing'],
#  ['rider', 'abandoning', 'bus', 'train', 'problem', 'climate', 'change'],
#  ['climate', 'taking', 'growing', 'role', 'voter', 'research', 'suggests'],
#  ['behind', 'time', 'opinjon', 'post', 'card', 'world', 'fire'],
#  ['lesson', 'plan', 'climate', 'change', 'people', 'already', 'harmed'],
#  ['opinion', 'slow', 'climate', 'change', 'without', 'energy', 'company'],
#  ['scientist', 'trace', 'extreme', 'heat', 'australia', 'climate', 'change'],
#  ['automaker', 'shift', 'gear', 'climate', 'change'],
#  ['new',
#   'york',
#   'change',
#   'outdoor',
#   'dining',
#   'rule',
#   'leaving',
#   'restaurant',
#   'scrambling'],
#  ['meat',
#   'business',
#   'big',
#   'contributor',
#   'climate',
#   'change',
#   'face',
#   'major',
#   'test'],
#  ['conflict',
#   'climate',
#   'change',
#   'ravage',
#   'syria',
#   'agricultural',
#   'heartland'],
#  ['american', 'worried', 'warming', 'climate', 'change'],
#  ['friday', 'highlight', 'climate', 'summit'],
#  ['watch', 'team', 'behind', 'look', 'urge', 'climate', 'action'],
#  ['pacific',
#   'island',
#   'russia',
#   'test',
#   'battle',
#   'plan',
#   'climate',
#   'change'],
#  ['agency', 'issue', 'climate', 'change', 'warning', 'summit'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['climate', 'protester', 'world', 'leader', 'planet', 'different', 'world'],
#  ['leader', 'came', 'view', 'climate', 'change', 'fake', 'science'],
#  ['opinion', 'watching', 'earth', 'burn'],
#  ['climate',
#   'change',
#   'denialists',
#   'say',
#   'polar',
#   'bear',
#   'fine',
#   'scientist',
#   'pushing',
#   'back'],
#  ['infrastructure', 'bill', 'recognizes', 'climate', 'change', 'crisis'],
#  ['kirk',
#   'smith',
#   'towering',
#   'figure',
#   'environmental',
#   'science',
#   'dy',
#   '73'],
#  ['already',
#   'vulnerable',
#   'penguin',
#   'study',
#   'find',
#   'climate',
#   'change',
#   'another',
#   'danger'],
#  ['effect', 'climate', 'change', 'tornado', 'know'],
#  ['defense', 'department', 'redefines', 'climate', 'change'],
#  ['planet', 'seen', 'sudden', 'warming', 'wiped', 'almost', 'everything'],
#  ['china',
#   'unveils',
#   'ambitious',
#   'plan',
#   'curb',
#   'climate',
#   'change',
#   'emission'],
#  ['restoring',
#   'farmland',
#   'could',
#   'drastically',
#   'slow',
#   'extinction',
#   'fight',
#   'climate',
#   'change'],
#  ['battle', 'climate', 'change', 'begin', 'air', 'conditioner'],
#  ['british', 'columbia', 'flooding', 'worse', 'climate', 'change'],
#  ['week', 'disaster', 'tell', 'u', 'climate', 'pandemic'],
#  ['germany',
#   'flood',
#   'climate',
#   'change',
#   'move',
#   'center',
#   'campaign',
#   'toll',
#   'mount'],
#  ['amid',
#   'extreme',
#   'weather',
#   'shift',
#   'among',
#   'republican',
#   'climate',
#   'change'],
#  ['scrub', 'climate', 'website', 'climate', 'change'],
#  ['thought', 'would', 'die', 'inside', 'myanmar', 'risky', 'pursuit', 'jade'],
#  ['much', 'climate', 'change', 'scrubbed', 'federal', 'website', 'lot'],
#  ['climate', 'change', 'scaring', 'kid', 'talk'],
#  ['city', 'trying', 'avert', 'gridlock', 'coronavirus', 'lockdown'],
#  ['fed', 'long', 'reticent', 'started', 'talk', 'climate', 'change'],
#  ['climate', 'change', 'seen', 'threat', 'security'],
#  ['opinion', 'climate', 'change', 'bad', 'health'],
#  ['tinker', 'environment', 'fight', 'climate', 'change'],
#  ['marine', 'lab', 'water', 'edge', 'threatened', 'climate', 'change'],
#  ['historic', 'arctic', 'heat', 'wave', 'roast', 'siberia'],
#  ['path', 'climate', 'change', 'beyond', 'paris'],
#  ['opinion', 'let', 'get', 'started', 'fighting', 'climate', 'change'],
#  ['switch',
#   'republican',
#   'start',
#   'citing',
#   'climate',
#   'change',
#   'driving',
#   'policy'],
#  ['opinion', 'climate', 'change', 'cost', 'u', 'even', 'think'],
#  ['scientist',
#   'link',
#   'hurricane',
#   'harvey',
#   'record',
#   'rainfall',
#   'climate',
#   'change'],
#  ['opinion', 'protecting', 'forest', 'climate', 'change'],
#  ['opinion',
#   'climate',
#   'change',
#   'biden',
#   'trillion',
#   'plan',
#   'big',
#   'enough'],
#  ['protesting',
#   'climate',
#   'change',
#   'young',
#   'people',
#   'take',
#   'street',
#   'global',
#   'strike'],
#  ['opinion',
#   'ukraine',
#   'war',
#   'could',
#   'stall',
#   'climate',
#   'action',
#   'galvanize'],
#  ['latest',
#   'national',
#   'climate',
#   'plan',
#   'still',
#   'fall',
#   'far',
#   'short',
#   'report',
#   'warns'],
#  ['fed', 'deal', 'climate', 'change'],
#  ['make', 'sense', 'robert', 'court'],
#  ['opinion', 'stop', 'freaking', 'tackle', 'climate', 'change'],
#  ['opinion',
#   'world',
#   'solved',
#   'ozone',
#   'problem',
#   'solve',
#   'climate',
#   'change'],
#  ['biden', 'announces', 'trillion', 'climate', 'plan'],
#  ['exxon', 'mobil', 'face', 'activist', 'investor', 'climate', 'change'],
#  ['climate', 'change', 'eye'],
#  ['focus', 'abortion', 'access', 'people', 'dying'],
#  ['climate', 'change', 'burn', 'way', 'pop', 'chart'],
#  ['storm', 'intensify', 'job', 'tv', 'weather', 'person', 'get', 'serious'],
#  ['climate',
#   'change',
#   'could',
#   'increase',
#   'risk',
#   'wildfire',
#   '50',
#   'century',
#   'end'],
#  ['survive', 'climate', 'change'],
#  ['climate', 'disaster', 'pile', 'radical', 'proposal', 'gain', 'traction'],
#  ['climate',
#   'change',
#   'devastating',
#   'coral',
#   'reef',
#   'worldwide',
#   'major',
#   'report',
#   'say'],
#  ['opinion',
#   'al',
#   'gore',
#   'hope',
#   'climate',
#   'crisis',
#   'america',
#   'must',
#   'lead'],
#  ['opinion', 'teaching', 'truth', 'climate', 'change'],
#  ['glimpse',
#   'america',
#   'future',
#   'climate',
#   'change',
#   'mean',
#   'trouble',
#   'power',
#   'grid'],
#  ['opinion', 'know', 'climate', 'change'],
#  ['opinion', 'maybe', 'doomed'],
#  ['american', 'outlier', 'view', 'climate', 'change'],
#  ['global', 'warming', 'real', 'american', 'say', 'yes'],
#  ['really', 'behind', 'corporate', 'promise', 'climate', 'change'],
#  ['climate', 'connection', 'california', 'wildfire'],
#  ['bitcoin', 'climate', 'change', 'impact', 'scrutiny'],
#  ['ready', 'climate', 'reality'],
#  ['climate', 'panel', 'endorses', 'ceiling', 'global', 'emission'],
#  ['united',
#   'nation',
#   'warns',
#   'catastrophic',
#   'pathway',
#   'current',
#   'climate',
#   'pledge'],
#  ['climate', 'change', 'bring', 'wetter', 'storm', 'study', 'say'],
#  ['cop26', 'summit', 'urgent', 'plea', 'combat', 'global', 'warning'],
#  ['human', 'imprint', 'climate', 'change', 'grows', 'clearer'],
#  ['bernie',
#   'sander',
#   'green',
#   'new',
#   'deal',
#   '16',
#   'trillion',
#   'climate',
#   'plan'],
#  ['american',
#   'see',
#   'climate',
#   'concern',
#   'even',
#   'amid',
#   'coronavirus',
#   'crisis'],
#  ['opinion', 'time', 'panic'],
#  ['trump',
#   'administration',
#   'remove',
#   'scientist',
#   'charge',
#   'assessing',
#   'climate',
#   'change'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['opinion', 'going', 'nowhere', 'fast', 'climate', 'year', 'year'],
#  ['went', 'moon', 'solve', 'climate', 'change'],
#  ['great', 'barrier', 'reef', 'lost', 'half', 'coral'],
#  ['washington', 'redskin', 'might', 'get', 'name', 'change'],
#  ['biden',
#   'intelligence',
#   'director',
#   'vow',
#   'put',
#   'climate',
#   'center',
#   'foreign',
#   'policy'],
#  ['race', 'warming', 'grower', 'try', 'outsmart', 'climate', 'change'],
#  ['climate',
#   'change',
#   'emerging',
#   'threat',
#   'financial',
#   'stability',
#   'regulator',
#   'say'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
# ...
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['australia', 'climate', 'bill', 'matter'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['cricket', 'sustainable', 'amid', 'climate', 'change'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['pace',
#   'climate',
#   'change',
#   'sends',
#   'economist',
#   'back',
#   'drawing',
#   'board'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['climate', 'change', 'could', 'worsen', 'supply', 'chain', 'turmoil'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['climate', 'change', 'linked', 'pakistan', 'flood', 'study', 'find'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['climate',
#   'change',
#   'preschooler',
#   'octonauts',
#   'explores',
#   'unmapped',
#   'ground'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['ease', 'climate', 'crisis', 'first', 'figure', 'work'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['climate',
#   'change',
#   'made',
#   'summer',
#   'hotter',
#   'drier',
#   'worldwide',
#   'study',
#   'find'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['climate',
#   'change',
#   'legislation',
#   'included',
#   'coronavirus',
#   'stimulus',
#   'deal'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['hurricane', 'larry', 'brings', 'snow', 'part', 'greenland'],
#  ['opinion', 'biden', 'climate', 'change'],
#  ['climate', 'change', 'affected', 'hurricane', 'dorian'],
#  ['heat',
#   'wave',
#   'age',
#   'climate',
#   'change',
#   'longer',
#   'frequent',
#   'dangerous'],
#  ['climate', 'change', 'battered', 'west', 'summer', 'even', 'begin'],
#  ['american', 'democracy', 'fails', 'climate', 'crisis'],
#  ['sustainability', 'climate', 'change', 'join', 'conversation', 'expert'],
#  ['boris',
#   'johnson',
#   'global',
#   'britain',
#   'inspired',
#   'vision',
#   'wishful',
#   'thinking'],
#  ['opinion', 'fix', 'income', 'wealth', 'inequality', 'america'],
#  ['biden',
#   'tell',
#   'official',
#   'prepare',
#   'climate',
#   'change',
#   'impact',
#   'economy'],
#  ['human',
#   'speeding',
#   'extinction',
#   'altering',
#   'natural',
#   'world',
#   'unprecedented',
#   'pace'],
#  ['opinion', 'biden', 'climate', 'change']]

# %%
# Create bigrams (two-word phrases) from the headlines
from gensim.models import Phrases

percent_freq = 0.02

bigram = Phrases(headlines, min_count=percent_freq * len(headlines))
for idx in range(len(headlines)):
    for token in bigram[headlines[idx]]:
        if "_" in token:
            # Token is a bigram, add to document.
            headlines[idx].append(token)

# %%
# Create a dictionary representation of the documents.
dictionary = Dictionary(headlines)
corpus = [dictionary.doc2bow(doc) for doc in headlines]

# %% [markdown]
# ## Training the LDA Model

# %%
# Train LDA model.

# Set training parameters.
num_topics = 10
chunksize = 200
passes = 20
iterations = 400
eval_every = None

# Make an index to word dictionary.
temp = dictionary[0]  # This is only to "load" the dictionary.
id2word = dictionary.id2token

model = LdaModel(
    corpus=corpus,
    id2word=id2word,
    chunksize=chunksize,
    alpha="auto",
    eta="auto",
    iterations=iterations,
    num_topics=num_topics,
    passes=passes,
    eval_every=eval_every,
)

# %%
top_topics = model.top_topics(corpus)
pprint.pprint(top_topics)
# Out:
# [([(0.0528405, 'climate'),
#    (0.050339833, 'change'),
#    (0.0480397, 'global'),
#    (0.039749976, 'hurricane'),
#    (0.039081845, 'thinking'),
#    (0.03890597, 'britain'),
#    (0.03821132, 'johnson'),
#    (0.03821132, 'inspired_vision'),
#    (0.03821132, 'inspired'),
#    (0.03821132, 'global_britain'),
#    (0.03821132, 'boris_johnson'),
#    (0.03821132, 'boris'),
#    (0.03821132, 'wishful'),
#    (0.03821132, 'wishful_thinking'),
#    (0.03821132, 'vision'),
#    (0.037438367, 'affected'),
#    (0.037298046, 'dorian'),
#    (0.036743704, 'affected_hurricane'),
#    (0.007447447, 'australia'),
#    (0.007059898, 'bill')],
#   -13.20312060867152),
#  ([(0.12130226, 'climate'),
#    (0.119116925, 'change'),
#    (0.025267016, 'economy'),
#    (0.025012378, 'impact'),
#    (0.024920572, 'biden'),
#    (0.024158109, 'coronavirus'),
#    (0.02363346, 'official'),
#    (0.023412224, 'deal'),
#    (0.022765832, 'dangerous'),
#    (0.02274552, 'impact_economy'),
#    (0.022444038, 'longer'),
#    (0.022444038, 'age'),
#    (0.022423735, 'prepare'),
#    (0.022423735, 'official_prepare'),
#    (0.022423735, 'biden_tell'),
#    (0.021548653, 'stimulus'),
#    (0.021548653, 'included'),
#    (0.021548653, 'coronavirus_stimulus'),
#    (0.021548653, 'legislation'),
#    (0.021548653, 'legislation_included')],
#   -13.585384208310776),
#  ([(0.17568354, 'climate'),
#    (0.15195176, 'change'),
#    (0.13601553, 'opinion'),
#    (0.0660735, 'biden'),
#    (0.012311376, 'plan'),
#    (0.008287318, 'china'),
#    (0.007861871, 'big'),
#    (0.0065897997, 'back'),
#    (0.0064532612, 'want'),
#    (0.0060316552, 'fight'),
#    (0.00601523, 'make'),
#    (0.005925045, 'company'),
#    (0.005374281, 'business'),
#    (0.0053742523, 'move'),
#    (0.0053740833, 'republican'),
#    (0.004987921, 'trillion'),
#    (0.0046635196, 'enough'),
#    (0.004537235, 'cop26'),
#    (0.0043002553, 'work'),
#    (0.004001592, 'next')],
#   -14.232489879789354),
#  ([(0.06798419, 'world'),
#    (0.049493313, 'expert'),
#    (0.047326215, 'pace'),
#    (0.04699506, 'conversation'),
#    (0.04699506, 'sustainability'),
#    (0.04699506, 'join_conversation'),
#    (0.0467308, 'extinction'),
#    (0.045687255, 'extinction_altering'),
#    (0.045687255, 'natural'),
#    (0.045687255, 'natural_world'),
#    (0.045687255, 'human_speeding'),
#    (0.045687255, 'unprecedented'),
#    (0.045687255, 'unprecedented_pace'),
#    (0.045687255, 'speeding'),
#    (0.044959314, 'change'),
#    (0.038910814, 'climate'),
#    (0.004526623, 'energy'),
#    (0.003081823, 'south'),
#    (0.0029522101, 'paris'),
#    (0.002818206, 'briefing')],
#   -14.746646511848327),
#  ([(0.09602965, 'climate'),
#    (0.08994221, 'change'),
#    (0.046557073, 'even'),
#    (0.046060227, 'summer'),
#    (0.044604708, 'tell'),
#    (0.04440993, 'west'),
#    (0.043995652, 'begin'),
#    (0.043196313, 'battered'),
#    (0.042435884, 'battered_west'),
#    (0.042435884, 'summer_even'),
#    (0.014087463, 'find'),
#    (0.013202319, 'study'),
#    (0.009122317, 'time'),
#    (0.008141209, 'disaster'),
#    (0.006390167, 'flood'),
#    (0.006214856, 'new'),
#    (0.0058462783, 'risk'),
#    (0.005329463, 'get'),
#    (0.0045673116, 'storm'),
#    (0.0045181597, 'let')],
#   -15.48748454361417),
#  ([(0.08882215, 'climate'),
#    (0.066651694, 'american'),
#    (0.06525464, 'heat'),
#    (0.057593893, 'heat_wave'),
#    (0.057593893, 'wave'),
#    (0.05349405, 'fails'),
#    (0.05349405, 'democracy'),
#    (0.05349405, 'american_democracy'),
#    (0.05187242, 'frequent'),
#    (0.05187242, 'longer_frequent'),
#    (0.02912688, 'change'),
#    (0.01746792, 'warming'),
#    (0.011547353, 'global'),
#    (0.005654634, 'water'),
#    (0.0056183757, 'extreme'),
#    (0.005248517, 'yes'),
#    (0.0047326176, 'activist'),
#    (0.0044936533, 'election'),
#    (0.004254621, 'try'),
#    (0.004194209, 'weather')],
#   -15.670415172936911),
#  ([(0.113070436, 'climate'),
#    (0.09643322, 'crisis'),
#    (0.07698357, 'join'),
#    (0.058055248, 'change'),
#    (0.015446914, 'report'),
#    (0.0130873835, 'science'),
#    (0.011851683, 'action'),
#    (0.010615515, 'take'),
#    (0.0094037, 'security'),
#    (0.009264112, 'trump'),
#    (0.009007661, 'warns'),
#    (0.008477511, 'major'),
#    (0.006855618, 'united'),
#    (0.0062902924, 'must'),
#    (0.0059909793, 'panel'),
#    (0.005838868, 'yet'),
#    (0.0052399277, '2020'),
#    (0.005239425, 'much'),
#    (0.0049406174, 'administration'),
#    (0.004940514, 'washington')],
#   -16.440241787194424),
#  ([(0.07134174, 'america'),
#    (0.06786163, 'opinion'),
#    (0.060328506, 'altering'),
#    (0.05776334, 'fix'),
#    (0.05776332, 'wealth'),
#    (0.05692838, 'inequality'),
#    (0.05692838, 'income'),
#    (0.05692838, 'fix_income'),
#    (0.05692838, 'wealth_inequality'),
#    (0.009902563, 'year'),
#    (0.009701887, 'could'),
#    (0.007263691, 'dy'),
#    (0.006818688, 'climate'),
#    (0.0059526213, 'u'),
#    (0.0058789477, 'global'),
#    (0.005687813, 'problem'),
#    (0.005633798, 'news'),
#    (0.0046407348, 'may'),
#    (0.0039255507, 'pledge'),
#    (0.003688705, 'good')],
#   -16.780636065328057),
#  ([(0.086945675, 'human'),
#    (0.06906597, 'climate'),
#    (0.057110243, 'change'),
#    (0.020039631, 'fight'),
#    (0.015939033, 'new'),
#    (0.015919, 'threat'),
#    (0.013778628, 'wildfire'),
#    (0.0121945, 'way'),
#    (0.011951347, 'arctic'),
#    (0.011102534, 'war'),
#    (0.0110647725, 'pose'),
#    (0.010103088, 'say'),
#    (0.009614229, 'behind'),
#    (0.008388604, 'pandemic'),
#    (0.008088392, 'ice'),
#    (0.007964431, 'first'),
#    (0.007373312, 'ukraine'),
#    (0.0064761005, 'worldwide'),
#    (0.0057894764, 'agency'),
#    (0.0054124547, 'different')],
#   -17.13779409283449),
#  ([(0.062288344, 'hurricane'),
#    (0.061139334, 'part'),
#    (0.060913473, 'greenland'),
#    (0.059738427, 'snow'),
#    (0.05862059, 'brings'),
#    (0.05862059, 'hurricane_larry'),
#    (0.05862059, 'larry'),
#    (0.05862059, 'brings_snow'),
#    (0.05862059, 'part_greenland'),
#    (0.0147105325, 'scientist'),
#    (0.012220463, 'fighting'),
#    (0.00961582, 'california'),
#    (0.009268285, 'amid'),
#    (0.0074776364, 'court'),
#    (0.0060758353, 'planet'),
#    (0.0058507165, 'effort'),
#    (0.0055443784, 'emission'),
#    (0.0055388203, 'kid'),
#    (0.005239874, 'national'),
#    (0.0043924777, 'carbon')],
#   -18.839919712833044)]
