# %%
from newsapi import NewsApiClient

# %%
newsapi = NewsApiClient(api_key='03946c5f6bee4ce0ba317e27a4df74e0')
top_headlines = newsapi.get_everything(q='climate OR climate change OR global warming OR environment OR forest fires OR natural disasters OR carbon OR ocean OR biodiversity OR endangered species OR extinction OR pollution OR plastic OR waste OR recycling OR sustainability OR renewable energy OR energy efficiency OR energy storage OR electric vehicles OR solar OR geothermal OR wind power OR hydroelectric OR nuclear OR contamination OR carbon emissions OR carbon footprint OR gasoline OR fossil fuels',
                                          language='en',)

# %%
top_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 8032,
#  'articles': [{'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Climate change: Invest in technology that removes CO2 - report',
#    'description': 'Emission cuts must be accompanied by greater efforts to remove CO2 from the atmosphere a new report says.',
#    'url': 'https://www.bbc.co.uk/news/science-environment-64321623',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/F360/production/_128340326_gettyimages-487818021.jpg',
#    'publishedAt': '2023-01-19T01:57:45Z',
#    'content': "Technology to remove the planet-warming greenhouse gas CO2 from our atmosphere must be urgently ramped up, leading climate experts say in a new report.\r\nScientists say big cuts in CO2 emissions won't… [+3192 chars]"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Molly Taft',
# ...
